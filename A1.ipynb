# %% [markdown]
# <h1><big><center>Object recognition and computer vision 2021/2022</center></big></h1>
#
# <h3><big><center><a href="http://www.di.ens.fr/~ponce/">Jean Ponce</a>, <a href="http://www.di.ens.fr/~laptev/">Ivan Laptev</a>, <a href="http://lear.inrialpes.fr/~schmid/">Cordelia Schmid</a> and <a href="http://www.di.ens.fr/~josef/">Josef Sivic</a></center></big></h3>
#
#
# <h2><big><center> Assignment 1: Instance-level recognition</center></big></h2>
#
# <h5><big><center>Adapted from practicals from <a href="http://www.robots.ox.ac.uk/~vgg/practicals/overview/index.html">Andrea Vedaldi and Andrew Zisserman</a>
#   <br>by <a href="https://www.di.ens.fr/~varol/">Gul Varol</a> and <a href="https://www.di.ens.fr/~iroccosp/">Ignacio Rocco</a></center></big></h5>
#
# </br>
# <p align="center">
# <img height=300px src="http://www.di.ens.fr/willow/teaching/recvis17orig/assignment1/images/image12.png"/></p>
# <p align="center"></p>

# %% [markdown]
# **STUDENT**:  Lucas Saban
#
# **EMAIL**:  lucas.saban@ensae.fr

# %% [markdown]
# # Guidelines
#
# The purpose of this assignment is that you get hands-on experience with the topics covered in class, which will help you understand these topics better. Therefore, ** it is imperative that you do this assignment yourself. No code sharing will be tolerated. **
#
# Once you have completed the assignment, you will submit the `ipynb` file containing **both** code and results. For this, make sure to **run your notebook completely before submitting**.
#
# The `ipynb` must be named using the following format: **A1_LASTNAME_Firstname.ipynb**, and submitted in the **class Moodle page**.

# %% [markdown]
# # Goal
# The goal of instance-level recognition is to match (recognize) a specific object or scene.  Examples include recognizing a specific building, such as Notre Dame, or a specific painting, such as `Starry Night’ by Van Gogh. The object is recognized despite changes in scale, camera viewpoint, illumination conditions and partial occlusion. An important application is image retrieval - starting from an image of an object of interest (the query), search  through an image dataset to obtain (or retrieve) those images that contain the target object.
#
# The goal of this assignment is to experiment and get basic practical experience with the methods that enable specific object recognition. It includes: (i) using SIFT features to obtain sparse matches between two images; (ii) using similarity co-variant detectors to cover changes in viewpoint; (iii) vector quantizing the SIFT descriptors into visual words to enable large scale retrieval; and (iv) constructing and using an image retrieval system to identify objects.

# %% [markdown]
# # Setup environment

# %% [markdown]
# ## Download and install CyVLFeat

# %%
# !wget -N http://www.di.ens.fr/willow/teaching/recvis_orig/assignment1/install_cyvlfeat.py
# %run install_cyvlfeat.py
# Out:
# --2022-10-13 18:55:49--  http://www.di.ens.fr/willow/teaching/recvis_orig/assignment1/install_cyvlfeat.py
# Résolution de www.di.ens.fr (www.di.ens.fr)… 129.199.99.14
# Connexion à www.di.ens.fr (www.di.ens.fr)|129.199.99.14|:80… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://www.di.ens.fr/willow/teaching/recvis_orig/assignment1/install_cyvlfeat.py [suivant]
# --2022-10-13 18:55:49--  https://www.di.ens.fr/willow/teaching/recvis_orig/assignment1/install_cyvlfeat.py
# Connexion à www.di.ens.fr (www.di.ens.fr)|129.199.99.14|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 304 Not Modified
# x vlfeat-0.9.20/apps/recognition/setupVoc.m
# x vlfeat-0.9.20/apps/recognition/trainEncoder.m
# x vlfeat-0.9.20/apps/recognition/traintest.m
# x vlfeat-0.9.20/apps/sift_mosaic.m
# x vlfeat-0.9.20/bin/
# x vlfeat-0.9.20/bin/glnx86/
# x vlfeat-0.9.20/bin/glnx86/aib
# x vlfeat-0.9.20/bin/glnx86/libvl.so
# x vlfeat-0.9.20/bin/glnx86/mser
# x vlfeat-0.9.20/bin/glnx86/sift
# x vlfeat-0.9.20/bin/glnx86/test_gauss_elimination
# x vlfeat-0.9.20/bin/glnx86/test_getopt_long
# x vlfeat-0.9.20/bin/glnx86/test_gmm
# x vlfeat-0.9.20/bin/glnx86/test_heap-def
# x vlfeat-0.9.20/bin/glnx86/test_host
# x vlfeat-0.9.20/bin/glnx86/test_imopv
# x vlfeat-0.9.20/bin/glnx86/test_kmeans
# x vlfeat-0.9.20/bin/glnx86/test_liop
# x vlfeat-0.9.20/bin/glnx86/test_mathop
# x vlfeat-0.9.20/bin/glnx86/test_mathop_abs
# x vlfeat-0.9.20/bin/glnx86/test_nan
# x vlfeat-0.9.20/bin/glnx86/test_qsort-def
# x vlfeat-0.9.20/bin/glnx86/test_rand
# x vlfeat-0.9.20/bin/glnx86/test_sqrti
# x vlfeat-0.9.20/bin/glnx86/test_stringop
# x vlfeat-0.9.20/bin/glnx86/test_svd2
# x vlfeat-0.9.20/bin/glnx86/test_threads
# x vlfeat-0.9.20/bin/glnx86/test_vec_comp
# x vlfeat-0.9.20/bin/glnxa64/
# x vlfeat-0.9.20/bin/glnxa64/aib
# x vlfeat-0.9.20/bin/glnxa64/libvl.so
# done!
# uncompressing vlfeat binaries...
# x vlfeat-0.9.20/bin/glnxa64/mser
# x vlfeat-0.9.20/bin/glnxa64/sift
# x vlfeat-0.9.20/bin/glnxa64/test_gauss_elimination
# x vlfeat-0.9.20/bin/glnxa64/test_getopt_long
# x vlfeat-0.9.20/bin/glnxa64/test_gmm
# x vlfeat-0.9.20/bin/glnxa64/test_heap-def
# x vlfeat-0.9.20/bin/glnxa64/test_host
# x vlfeat-0.9.20/bin/glnxa64/test_imopv
# x vlfeat-0.9.20/bin/glnxa64/test_kmeans
# x vlfeat-0.9.20/bin/glnxa64/test_liop
# x vlfeat-0.9.20/bin/glnxa64/test_mathop
# x vlfeat-0.9.20/bin/glnxa64/test_mathop_abs
# x vlfeat-0.9.20/bin/glnxa64/test_nan
# x vlfeat-0.9.20/bin/glnxa64/test_qsort-def
# x vlfeat-0.9.20/bin/glnxa64/test_rand
# x vlfeat-0.9.20/bin/glnxa64/test_sqrti
# x vlfeat-0.9.20/bin/glnxa64/test_stringop
# x vlfeat-0.9.20/bin/glnxa64/test_svd2
# x vlfeat-0.9.20/bin/glnxa64/test_threads
# x vlfeat-0.9.20/bin/glnxa64/test_vec_comp
# x vlfeat-0.9.20/bin/maci/
# x vlfeat-0.9.20/bin/maci/aib
# x vlfeat-0.9.20/bin/maci/libvl.dylib
# x vlfeat-0.9.20/bin/maci/mser
# x vlfeat-0.9.20/bin/maci/sift
# x vlfeat-0.9.20/bin/maci/test_gauss_elimination
# x vlfeat-0.9.20/bin/maci/test_getopt_long
# x vlfeat-0.9.20/bin/maci/test_gmm
# x vlfeat-0.9.20/bin/maci/test_heap-def
# x vlfeat-0.9.20/bin/maci/test_host
# x vlfeat-0.9.20/bin/maci/test_imopv
# x vlfeat-0.9.20/bin/maci/test_kmeans
# x vlfeat-0.9.20/bin/maci/test_liop
# x vlfeat-0.9.20/bin/maci/test_mathop
# x vlfeat-0.9.20/bin/maci/test_mathop_abs
# x vlfeat-0.9.20/bin/maci/test_nan
# x vlfeat-0.9.20/bin/maci/test_qsort-def
# x vlfeat-0.9.20/bin/maci/test_rand
# x vlfeat-0.9.20/bin/maci/test_sqrti
# x vlfeat-0.9.20/bin/maci/test_stringop
# x vlfeat-0.9.20/bin/maci/test_svd2
# x vlfeat-0.9.20/bin/maci/test_threads
# x vlfeat-0.9.20/bin/maci/test_vec_comp
# x vlfeat-0.9.20/bin/maci64/
# x vlfeat-0.9.20/bin/maci64/aib
# x vlfeat-0.9.20/bin/maci64/libvl.dylib
# x vlfeat-0.9.20/bin/maci64/mser
# x vlfeat-0.9.20/bin/maci64/sift
# x vlfeat-0.9.20/bin/maci64/test_gauss_elimination
# x vlfeat-0.9.20/bin/maci64/test_getopt_long
# x vlfeat-0.9.20/bin/maci64/test_gmm
# x vlfeat-0.9.20/bin/maci64/test_heap-def
# x vlfeat-0.9.20/bin/maci64/test_host
# x vlfeat-0.9.20/bin/maci64/test_imopv
# x vlfeat-0.9.20/bin/maci64/test_kmeans
# x vlfeat-0.9.20/bin/maci64/test_liop
# x vlfeat-0.9.20/bin/maci64/test_mathop
# x vlfeat-0.9.20/bin/maci64/test_mathop_abs
# x vlfeat-0.9.20/bin/maci64/test_nan
# x vlfeat-0.9.20/bin/maci64/test_qsort-def
# x vlfeat-0.9.20/bin/maci64/test_rand
# x vlfeat-0.9.20/bin/maci64/test_sqrti
# x vlfeat-0.9.20/bin/maci64/test_stringop
# x vlfeat-0.9.20/bin/maci64/test_svd2
# x vlfeat-0.9.20/bin/maci64/test_threads
# x vlfeat-0.9.20/bin/maci64/test_vec_comp
# x vlfeat-0.9.20/bin/win32/
# x vlfeat-0.9.20/bin/win32/aib.exe
# x vlfeat-0.9.20/bin/win32/mser.exe
# x vlfeat-0.9.20/bin/win32/msvcr100.dll
# x vlfeat-0.9.20/bin/win32/sift.exe
# x vlfeat-0.9.20/bin/win32/test_gauss_elimination.exe
# x vlfeat-0.9.20/bin/win32/test_getopt_long.exe
# x vlfeat-0.9.20/bin/win32/test_gmm.exe
# x vlfeat-0.9.20/bin/win32/test_heap-def.exe
# x vlfeat-0.9.20/bin/win32/test_host.exe
# x vlfeat-0.9.20/bin/win32/test_imopv.exe
# x vlfeat-0.9.20/bin/win32/test_kmeans.exe
# x vlfeat-0.9.20/bin/win32/test_liop.exe
# x vlfeat-0.9.20/bin/win32/test_mathop.exe
# x vlfeat-0.9.20/bin/win32/test_mathop_abs.exe
# x vlfeat-0.9.20/bin/win32/test_nan.exe
# x vlfeat-0.9.20/bin/win32/test_qsort-def.exe
# x vlfeat-0.9.20/bin/win32/test_rand.exe
# x vlfeat-0.9.20/bin/win32/test_sqrti.exe
# x vlfeat-0.9.20/bin/win32/test_stringop.exe
# x vlfeat-0.9.20/bin/win32/test_svd2.exe
# x vlfeat-0.9.20/bin/win32/test_threads.exe
# x vlfeat-0.9.20/bin/win32/test_vec_comp.exe
# x vlfeat-0.9.20/bin/win32/vl.dll
# x vlfeat-0.9.20/bin/win32/vl.lib
# x vlfeat-0.9.20/bin/win64/
# x vlfeat-0.9.20/bin/win64/aib.exe
# x vlfeat-0.9.20/bin/win64/mser.exe
# x vlfeat-0.9.20/bin/win64/msvcr100.dll
# x vlfeat-0.9.20/bin/win64/sift.exe
# x vlfeat-0.9.20/bin/win64/test_gauss_elimination.exe
# x vlfeat-0.9.20/bin/win64/test_getopt_long.exe
# x vlfeat-0.9.20/bin/win64/test_gmm.exe
# x vlfeat-0.9.20/bin/win64/test_heap-def.exe
# x vlfeat-0.9.20/bin/win64/test_host.exe
# x vlfeat-0.9.20/bin/win64/test_imopv.exe
# x vlfeat-0.9.20/bin/win64/test_kmeans.exe
# x vlfeat-0.9.20/bin/win64/test_liop.exe
# x vlfeat-0.9.20/bin/win64/test_mathop.exe
# x vlfeat-0.9.20/bin/win64/test_mathop_abs.exe
# x vlfeat-0.9.20/bin/win64/test_nan.exe
# x vlfeat-0.9.20/bin/win64/test_qsort-def.exe
# x vlfeat-0.9.20/bin/win64/test_rand.exe
# x vlfeat-0.9.20/bin/win64/test_sqrti.exe
# x vlfeat-0.9.20/bin/win64/test_stringop.exe
# x vlfeat-0.9.20/bin/win64/test_svd2.exe
# x vlfeat-0.9.20/bin/win64/test_threads.exe
# x vlfeat-0.9.20/bin/win64/test_vec_comp.exe
# x vlfeat-0.9.20/bin/win64/vl.dll
# x vlfeat-0.9.20/bin/win64/vl.lib
# x vlfeat-0.9.20/data/
# x vlfeat-0.9.20/data/box.pgm
# x vlfeat-0.9.20/data/box.sift
# x vlfeat-0.9.20/data/river1.jpg
# x vlfeat-0.9.20/data/river2.jpg
# x vlfeat-0.9.20/data/roofs1.jpg
# x vlfeat-0.9.20/data/roofs2.jpg
# x vlfeat-0.9.20/data/spots.jpg
# x vlfeat-0.9.20/doc/
# x vlfeat-0.9.20/doc/about.html
# x vlfeat-0.9.20/doc/api/
# x vlfeat-0.9.20/doc/api/aib.html
# x vlfeat-0.9.20/doc/api/aib_8c.html
# x vlfeat-0.9.20/doc/api/aib_8h.html
# x vlfeat-0.9.20/doc/api/annotated.html
# x vlfeat-0.9.20/doc/api/array_8h.html
# x vlfeat-0.9.20/doc/api/bc_s.png
# x vlfeat-0.9.20/doc/api/bdwn.png
# x vlfeat-0.9.20/doc/api/bug.html
# x vlfeat-0.9.20/doc/api/citelist.html
# x vlfeat-0.9.20/doc/api/classes.html
# x vlfeat-0.9.20/doc/api/closed.png
# x vlfeat-0.9.20/doc/api/conventions.html
# x vlfeat-0.9.20/doc/api/covdet-affine-adaptation.html
# x vlfeat-0.9.20/doc/api/covdet-corner-types.html
# x vlfeat-0.9.20/doc/api/covdet-differential.html
# x vlfeat-0.9.20/doc/api/covdet-dominant-orientation.html
# x vlfeat-0.9.20/doc/api/covdet-fundamentals.html
# x vlfeat-0.9.20/doc/api/covdet-normalization.png
# x vlfeat-0.9.20/doc/api/covdet-principles.html
# x vlfeat-0.9.20/doc/api/covdet.html
# x vlfeat-0.9.20/doc/api/covdet.png
# x vlfeat-0.9.20/doc/api/covdet_8c.html
# x vlfeat-0.9.20/doc/api/covdet_8h.html
# x vlfeat-0.9.20/doc/api/deprecated.html
# x vlfeat-0.9.20/doc/api/dev.html
# x vlfeat-0.9.20/doc/api/dir_68267d1309a1af8e8297ef4c3efbcdba.html
# x vlfeat-0.9.20/doc/api/dir_8dd540b382164c224dfa1eb6e8a3add6.html
# x vlfeat-0.9.20/doc/api/dir_cb851817d6f77244316f2683559617a2.html
# x vlfeat-0.9.20/doc/api/doxygen.css
# x vlfeat-0.9.20/doc/api/doxygen.png
# x vlfeat-0.9.20/doc/api/dsift-geom.png
# x vlfeat-0.9.20/doc/api/dsift.html
# x vlfeat-0.9.20/doc/api/dsift_8c.html
# x vlfeat-0.9.20/doc/api/dsift_8h.html
# x vlfeat-0.9.20/doc/api/files.html
# x vlfeat-0.9.20/doc/api/fisher-derivation.html
# x vlfeat-0.9.20/doc/api/fisher-fundamentals.html
# x vlfeat-0.9.20/doc/api/fisher-kernel.html
# x vlfeat-0.9.20/doc/api/fisher.html
# x vlfeat-0.9.20/doc/api/fisher_8c.html
# x vlfeat-0.9.20/doc/api/fisher_8h.html
# x vlfeat-0.9.20/doc/api/frame-canonical.png
# x vlfeat-0.9.20/doc/api/frame-types.png
# x vlfeat-0.9.20/doc/api/ftv2blank.png
# x vlfeat-0.9.20/doc/api/ftv2doc.png
# x vlfeat-0.9.20/doc/api/ftv2folderclosed.png
# x vlfeat-0.9.20/doc/api/ftv2folderopen.png
# x vlfeat-0.9.20/doc/api/ftv2lastnode.png
# x vlfeat-0.9.20/doc/api/ftv2link.png
# x vlfeat-0.9.20/doc/api/ftv2mlastnode.png
# x vlfeat-0.9.20/doc/api/ftv2mnode.png
# x vlfeat-0.9.20/doc/api/ftv2node.png
# x vlfeat-0.9.20/doc/api/ftv2plastnode.png
# x vlfeat-0.9.20/doc/api/ftv2pnode.png
# x vlfeat-0.9.20/doc/api/ftv2splitbar.png
# x vlfeat-0.9.20/doc/api/ftv2vertline.png
# x vlfeat-0.9.20/doc/api/functions.html
# x vlfeat-0.9.20/doc/api/functions_b.html
# x vlfeat-0.9.20/doc/api/functions_c.html
# x vlfeat-0.9.20/doc/api/functions_d.html
# x vlfeat-0.9.20/doc/api/functions_e.html
# x vlfeat-0.9.20/doc/api/functions_f.html
# x vlfeat-0.9.20/toolbox/xtest/vl_test_grad.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_hikmeans.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_hog.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_homkermap.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_ihashsum.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_ikmeans.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_imarray.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_imdisttf.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_imintegral.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_imsmooth.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_imwbackward.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_init.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_inthist.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_kdtree.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_kmeans.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_lbp.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_liop.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_mser.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_phow.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_plotbox.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_pr.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_printsize.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_roc.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_sift.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_slic.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_svmtrain.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_twister.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_vlad.m
# x vlfeat-0.9.20/toolbox/xtest/vl_test_whistc.m
# x vlfeat-0.9.20/vl/
# x vlfeat-0.9.20/vl/aib.c
# x vlfeat-0.9.20/vl/aib.h
# x vlfeat-0.9.20/vl/array.c
# x vlfeat-0.9.20/vl/array.h
# x vlfeat-0.9.20/vl/covdet.c
# x vlfeat-0.9.20/vl/covdet.h
# x vlfeat-0.9.20/vl/dsift.c
# x vlfeat-0.9.20/vl/dsift.h
# x vlfeat-0.9.20/vl/fisher.c
# x vlfeat-0.9.20/vl/fisher.h
# x vlfeat-0.9.20/vl/float.th
# x vlfeat-0.9.20/vl/generic.c
# x vlfeat-0.9.20/vl/generic.h
# x vlfeat-0.9.20/vl/getopt_long.c
# x vlfeat-0.9.20/vl/getopt_long.h
# x vlfeat-0.9.20/vl/gmm.c
# x vlfeat-0.9.20/vl/gmm.h
# x vlfeat-0.9.20/vl/heap-def.h
# x vlfeat-0.9.20/vl/hikmeans.c
# x vlfeat-0.9.20/vl/hikmeans.h
# x vlfeat-0.9.20/vl/hog.c
# x vlfeat-0.9.20/vl/hog.h
# x vlfeat-0.9.20/vl/homkermap.c
# x vlfeat-0.9.20/vl/homkermap.h
# x vlfeat-0.9.20/vl/host.c
# x vlfeat-0.9.20/vl/host.h
# x vlfeat-0.9.20/vl/ikmeans.c
# x vlfeat-0.9.20/vl/ikmeans.h
# x vlfeat-0.9.20/vl/ikmeans_elkan.tc
# x vlfeat-0.9.20/vl/ikmeans_init.tc
# x vlfeat-0.9.20/vl/ikmeans_lloyd.tc
# x vlfeat-0.9.20/vl/imopv.c
# x vlfeat-0.9.20/vl/imopv.h
# x vlfeat-0.9.20/vl/imopv_sse2.c
# x vlfeat-0.9.20/vl/imopv_sse2.h
# x vlfeat-0.9.20/vl/kdtree.c
# x vlfeat-0.9.20/vl/kdtree.h
# x vlfeat-0.9.20/vl/kmeans.c
# x vlfeat-0.9.20/vl/kmeans.h
# x vlfeat-0.9.20/vl/lbp.c
# x vlfeat-0.9.20/vl/lbp.h
# x vlfeat-0.9.20/vl/liop.c
# x vlfeat-0.9.20/vl/liop.h
# x vlfeat-0.9.20/vl/mathop.c
# x vlfeat-0.9.20/vl/mathop.h
# x vlfeat-0.9.20/vl/mathop_avx.c
# x vlfeat-0.9.20/vl/mathop_avx.h
# x vlfeat-0.9.20/vl/mathop_sse2.c
# x vlfeat-0.9.20/vl/mathop_sse2.h
# x vlfeat-0.9.20/vl/mser.c
# x vlfeat-0.9.20/vl/mser.h
# x vlfeat-0.9.20/vl/pgm.c
# x vlfeat-0.9.20/vl/pgm.h
# x vlfeat-0.9.20/vl/qsort-def.h
# x vlfeat-0.9.20/vl/quickshift.c
# x vlfeat-0.9.20/vl/quickshift.h
# x vlfeat-0.9.20/vl/random.c
# x vlfeat-0.9.20/vl/random.h
# x vlfeat-0.9.20/vl/rodrigues.c
# x vlfeat-0.9.20/vl/rodrigues.h
# x vlfeat-0.9.20/vl/scalespace.c
# x vlfeat-0.9.20/vl/scalespace.h
# x vlfeat-0.9.20/vl/shuffle-def.h
# x vlfeat-0.9.20/vl/sift.c
# x vlfeat-0.9.20/vl/sift.h
# x vlfeat-0.9.20/vl/slic.c
# x vlfeat-0.9.20/vl/slic.h
# x vlfeat-0.9.20/vl/stringop.c
# x vlfeat-0.9.20/vl/stringop.h
# x vlfeat-0.9.20/vl/svm.c
# x vlfeat-0.9.20/vl/svm.h
# x vlfeat-0.9.20/vl/svmdataset.c
# x vlfeat-0.9.20/vl/svmdataset.h
# x vlfeat-0.9.20/vl/vlad.c
# x vlfeat-0.9.20/vl/vlad.h
# x vlfeat-0.9.20/vlfeat.sln
# x vlfeat-0.9.20/vlfeat.vcproj
# x vlfeat-0.9.20/vlfeat.xcodeproj/
# x vlfeat-0.9.20/vlfeat.xcodeproj/project.pbxproj
# x vlfeat-0.9.20/vlfeat.xcodeproj/xcshareddata/
# x vlfeat-0.9.20/vlfeat.xcodeproj/xcshareddata/xcschemes/
# x vlfeat-0.9.20/vlfeat.xcodeproj/xcshareddata/xcschemes/make doc-api.xcscheme
# x vlfeat-0.9.20/vlfeat.xcodeproj/xcshareddata/xcschemes/make info.xcscheme
# x vlfeat-0.9.20/vlfeat.xcodeproj/xcshareddata/xcschemes/make.xcscheme
# done!
# cloning pyvlfeat repo to cyvlfeat_git folder...
# Clonage dans 'cyvlfeat_git'...
# done!
# building cyvlfeat...
# /Users/g0bel1n/opt/anaconda3/envs/mva_vision-env/lib/python3.9/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File:
Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:78:37: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:79:41: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:80:41: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:81:41: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:82:36: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:83:41: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:84:23: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:85:26: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:86:39: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:87:39: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:88:39: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:89:34: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/sift.pxd:90:39: Declarations should not be declared inline.
# warning: cyvlfeat/_vl/mathop.pxd:27:15: Declarations should not be declared inline.
# xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
# error: command '/usr/bin/clang' failed with exit code 1
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File ~/mva-vision/install_cyvlfeat.py:51
#      50 #!python setup.py build
# ---> 51 check_output('VLFEAT_DIR="$(dirname `pwd`)/'+vlfeat_ver+'/" python setup.py build', shell=True)
#      52 print('done!')
#
# File ~/opt/anaconda3/envs/mva_vision-env/lib/python3.9/subprocess.py:424, in check_output(timeout, *popenargs, **kwargs)
#     422     kwargs['input'] = empty
# --> 424 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     425            **kwargs).stdout
#
# File ~/opt/anaconda3/envs/mva_vision-env/lib/python3.9/subprocess.py:528, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     527     if check and retcode:
# --> 528         raise CalledProcessError(retcode, process.args,
#     529                                  output=stdout, stderr=stderr)
#     530 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command 'VLFEAT_DIR="$(dirname `pwd`)/vlfeat-0.9.20/" python setup.py build' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# File ~/mva-vision/install_cyvlfeat.py:85
#      83     print('Installation of cyvlfeat is finished')
#      84 except CalledProcessError as e:
# ---> 85     print(str(error, 'utf-8'))
#      86     print('failed!')
#
# NameError: name 'error' is not defined

# %% [markdown]
# ## Imports

# %%
import os 

os.listdir("..")
# Out:
# ['cyvlfeat',
#  'vlfeat-0.9.20',
#  'install_cyvlfeat.py',
#  'vlfeat-0.9.20-bin.tar.gz',
#  '.git']

# %%
from cyvlfeat_git import cyvlfeat
import numpy as np
from skimage.io import imread
from skimage.transform import resize, rotate
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
from cyvlfeat_git.plot import plotframes
from scipy.io import loadmat
import numpy as np

# change some default matplotlib parameters
mpl.rcParams['axes.grid'] = False
mpl.rcParams['figure.dpi'] = 120

# ignore warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 from cyvlfeat_git import cyvlfeat
#       2 import numpy as np
#       3 from skimage.io import imread
#
# File ~/mva-vision/cyvlfeat_git/cyvlfeat/__init__.py:1
# ----> 1 import fisher
#       2 import generic
#       3 import gmm
#
# ModuleNotFoundError: No module named 'fisher'

# %% [markdown]
# ## Download and uncompress data

# %%
import os

os.listdir()
# Out:
# ['cyvlfeat',
#  'vlfeat-0.9.20',
#  'A1.ipynb',
#  'install_cyvlfeat.py',
#  'vlfeat-0.9.20-bin.tar.gz',
#  '.git']

# %%
print('downloading assignment images...')
# !wget -c http://www.di.ens.fr/willow/teaching/recvis_orig/assignment1/A1_images.tar.gz
print('done!')
print('uncompressing...')
# !tar -xzf A1_images.tar.gz
print('done!')
# Out:
# downloading assignment images...
# --2022-10-13 18:49:48--  http://www.di.ens.fr/willow/teaching/recvis_orig/assignment1/A1_images.tar.gz
# Résolution de www.di.ens.fr (www.di.ens.fr)… 129.199.99.14
# Connexion à www.di.ens.fr (www.di.ens.fr)|129.199.99.14|:80… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://www.di.ens.fr/willow/teaching/recvis_orig/assignment1/A1_images.tar.gz [suivant]
# --2022-10-13 18:49:48--  https://www.di.ens.fr/willow/teaching/recvis_orig/assignment1/A1_images.tar.gz
# Connexion à www.di.ens.fr (www.di.ens.fr)|129.199.99.14|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : non indiqué [application/x-gzip]
# Sauvegarde en : « A1_images.tar.gz »
#
# A1_images.tar.gz        [ <=>                ] 242,70M  12,3MB/s    ds 20s
#
# 2022-10-13 18:50:08 (12,0 MB/s) - « A1_images.tar.gz » sauvegardé [254489201]
#
# done!
# uncompressing...
# done!

# %% [markdown]
# # Part 1: Sparse features for matching specific objects in images

# %% [markdown]
# ## Feature point detection
#
# The SIFT feature has both a *detector* and a *descriptor*. The *detector* used in SIFT corresponds to the "difference of Gaussians" (DoG) detector, which is an approximation of the "Laplacian of Gaussian"  (LoG) detector.
#
# We will start by computing and visualizing the SIFT feature detections (usually called frames) for two images of the same object (a building facade). Load an image, rotate and scale it, and then display the original and transformed pair:

# %%
# Load an image
im1 = imread('data/oxbuild_lite/all_souls_000002.jpg')

# Let the second image be a rotated and scaled version of the first
im1prime = rotate(np.pad(im1, ((0,0), (200,200),(0,0)), 'constant'), 35, 'bilinear')
h, w, _ = im1prime.shape
im1prime = resize(im1prime, (int(0.7 * h), int(0.7 * w)))
im1prime = (255 * im1prime).astype(np.uint8)

f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(im1)
ax2.imshow(im1prime)
plt.show()

# %% [markdown]
# A SIFT frame is a circle with an orientation and is specified by four parameters: the center $x$, $y$, the scale $s$, and the rotation $\theta$ (in radians), resulting in a vector of four parameters $(x, y, s, \theta)$.
#
# Now compute and visualise the SIFT feature detections (frames):

# %%
def rgb2gray(rgb):
    return np.float32(np.dot(rgb[...,:3], [0.299, 0.587, 0.114])/255.0)

# %%
import cyvlfeat as cy

# %%
cy.

# %%
# Compute SIFT features for each

[frames1, descrs1] = cyvlfeat.cyvlfeat.sift.sift(rgb2gray(im1), peak_thresh=0.01)

[frames1prime, descrs1prime] = cyvlfeat.sift.sift(rgb2gray(im1prime), peak_thresh=0.01)

f, (ax1, ax2) = plt.subplots(1, 2)
plt.sca(ax1)
plt.imshow(im1)
plotframes(frames1, linewidth=1)

plt.sca(ax2)
plt.imshow(im1prime)
plotframes(frames1prime, linewidth=1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [10], line 3
#       1 # Compute SIFT features for each
# ----> 3 [frames1, descrs1] = cyvlfeat.cyvlfeat.sift.sift(rgb2gray(im1), peak_thresh=0.01)
#       5 [frames1prime, descrs1prime] = cyvlfeat.sift.sift(rgb2gray(im1prime), peak_thresh=0.01)
#       7 f, (ax1, ax2) = plt.subplots(1, 2)
#
# AttributeError: module 'cyvlfeat' has no attribute 'cyvlfeat'

# %% [markdown]
# Examine the second image and its rotated and scaled version and convince yourself that the detections overlap the same scene regions (even though the circles' positions have moved in the image and their radius' have changed).
# This demonstrates that the detection process (is co-variant or equi-variant) with translations, rotations and isotropic scalings. This class of transformations is known as a similarity or equiform.

# %% [markdown]
# ### :: TASK 1.1 ::
#
# Now repeat the exercise with a pair of natural images.
#
# Start by loading the second one: `data/oxbuild_lite/all_souls_000015.jpg`
#
# Plot the images and feature frames. Do not apply a synthetic rotation. Again you should see that many of the detections overlap the same scene region. Note that, while repeatability occurs for the pair of natural views, it is much better for the synthetically rotated pair.

# %%
##########################
#                        #
#  WRITE YOUR CODE HERE  #
#                        #
##########################

# %% [markdown]
# The number of detected features can be controlled by changing the peakThreshold option. A larger value will select features that correspond to higher contrast structures in the image.

# %% [markdown]
# ### :: TASK 1.2 ::
#
# ***For the same image, produce 3 sub-figures with different values of peakThreshold. Comment.***

# %%
##########################
#                        #
#  WRITE YOUR CODE HERE  #
#                        #
##########################

# %% [markdown]
# ######################
#
# WRITE YOUR ANSWER HERE
#
# ######################

# %% [markdown]
# ## Feature point description and matching

# %% [markdown]
# ### Introduction to feature descriptors
#
#
# The parameters $(t_x, t_y, s, \theta)$ of the detected *frames*,  can be used to extract a **scaled and oriented RGB patch** around $(t_x,t_y)$, used to *describe* the feature point.
#
# The simplest possible descriptor would be to (i) resize these patches to a common size (eg. 30x30) and (ii) flatten to a vector. However, in practice we use more sophisticated descriptors such as SIFT, that is based on histograms of gradient orientations.

# %% [markdown]
# ### :: TASK 1.3 ::
#
#
# ***What is the interest of using SIFT descriptors over these flattened RGB patches?***

# %% [markdown]
# ######################
#
#    WRITE YOUR ANSWER HERE
#
# ######################

# %% [markdown]
# ### Descriptor matching
# SIFT descriptors are 128-dimensional vectors, and can be directly *matched* to find correspondences between images. We will start with the simplest matching scheme (first nearest neighbour of descriptors in terms of Euclidean distance) and then add more sophisticated methods to eliminate any mismatches.
#
# Be careful, the descriptor output by `cyvlfeat.sift.sift` is an array of integers, to avoid issues when substracting descriptors, convert it to an array of floats first with `descriptor = descriptor.astype(np.float64)`.
#
# In the following section, use a peak threshold of 0.01 .

# %% [markdown]
# ### :: TASK 1.4 ::
#
#
# For each descriptor in im1, assign a matching descriptor in im2 by picking its first nearest neighbour.
#
# Populate the second column of the matches vector.

# %%
# number of detections in image 1
N_frames1 = frames1.shape[0]
# allocate matrix for storing the matches
matches=np.zeros((N_frames1,2),dtype=np.int)
# the first column of the matrix are the indices on image 1: 0,1,2,....,N_frames1-1
matches[:,0]=range(N_frames1)

# write code to find the matches in image 2 of each feature in image 1 
# populate the second column of the matches vector

##########################
#                        #
#  WRITE YOUR CODE HERE  #
#                        #
##########################

# %%
# plot matches
plt.figure()
plt.imshow(np.concatenate((im1,im2),axis=1))
for i in range(N_frames1):
    j=matches[i,1]
    # plot dots at feature positions
    plt.gca().scatter([frames1[i,0],im1.shape[1]+frames2[j,0]], [frames1[i,1],frames2[j,1]], s=5, c='green')
    # plot lines
    plt.plot([frames1[i,0],im1.shape[1]+frames2[j,0]],[frames1[i,1],frames2[j,1]],linewidth=0.5)
plt.show()

# %% [markdown]
# ## Improving SIFT matching (i) using Lowe’s second nearest neighbour test

# %% [markdown]
# Lowe introduced a second nearest neighbour (2nd NN) test to identify, and hence remove, ambiguous matches. The idea is to identify distinctive matches by a threshold on the ratio of first to second NN distances.
#
# The ratio is:  $$NN_{ratio} = \frac{1^{st}\text{NN distance}}{2^{nd}\text{NN distance}}.$$

# %% [markdown]
# ### :: TASK 1.5 ::
#
# ***For each descriptor in im1, compute the ratio between the first and second nearest neighbour distances.***
#
# ***Populate the ratio vector.***

# %%
# allocate matrix for storing the matches
ratio=np.zeros((N_frames1,1))

# write code to find the 1st/2nd NN ratio for each descriptor in im1
# populate the ratio vector

##########################
#                        #
#  WRITE YOUR CODE HERE  #
#                        #
##########################

# %% [markdown]
# The ratio vector will be now used to retain only the matches that are above a given threshold.
#
# A value of $NN_{threshold} = 0.8$ is often a good compromise between losing too many matches and rejecting mismatches.

# %%
NN_threshold=0.8

filtered_indices = np.flatnonzero(ratio<NN_threshold)
filtered_matches = matches[filtered_indices,:]

# %%
# plot matches
plt.figure()
plt.imshow(np.concatenate((im1,im2),axis=1))
for idx in range(filtered_matches.shape[0]):
    i=filtered_matches[idx,0]
    j=filtered_matches[idx,1]
    # plot dots at feature positions
    plt.gca().scatter([frames1[i,0],im1.shape[1]+frames2[j,0]], [frames1[i,1],frames2[j,1]], s=5, c='green') 
    # plot lines
    plt.plot([frames1[i,0],im1.shape[1]+frames2[j,0]],[frames1[i,1],frames2[j,1]],linewidth=0.5)
plt.show()

# %% [markdown]
# ## Improving SIFT matching (ii) by geometric verification

# %% [markdown]
# In addition to the 2nd NN test, we can also require consistency between the matches and a geometric transformation between the images. For the moment we will look for matches that are consistent with a similarity transformation:
#
# $$\begin{bmatrix} x_2 \\ y_2 \end{bmatrix} =
# sR(\theta) \begin{bmatrix} x_1 \\ y_1 \end{bmatrix} + \begin{bmatrix} t_x \\ t_y \end{bmatrix} $$
#
# which consists of a rotation by $\theta$, an isotropic scaling (i.e. same in all directions) by s, and a translation by a vector $(t_x, t_y)$. This transformation is specified by four parameters $(s,\theta,t_x,t_y)$ and can be computed from a single correspondence between SIFT detections in each image.

# %% [markdown]
# ### :: TASK 1.6 ::
#
# Given a detected feature with parameters $(x_1, y_1, s_1, \theta_1)$ in image $1$ matching a feature $(x_2, y_2, s_2, \theta_2)$ in image $2$, work out how to find out the parameters $(t_x,t_y,s,\theta)$ of the transformation mapping points from image $1$ to image $2$.

# %% [markdown]
# $$\theta=\text{COMPLETE HERE}$$
# $$s=\text{COMPLETE HERE}$$
# $$\begin{bmatrix} t_x \\ t_y \end{bmatrix} =\text{COMPLETE HERE}$$

# %% [markdown]
# The matches consistent with a similarity can then be found using the RANSAC algorithm, described by the following steps:
#
# For each tentative correspondence in turn:
#
# * compute the similarity transformation;
# * map all the SIFT detections in one image to the other using this transformation;
# * accept matches that are within a threshold distance to the mapped detection (inliers);
# * count the number of accepted matches;
# * optionally, fit a more accurate affine transformation or homography to the accepted matches and test re-validate the matches.
#
# Finally, choose the transformation with the highest count of inliers
#
# After this algorithm the inliers are consistent with the transformation and are retained, and most mismatches should now be removed.

# %% [markdown]
# ### :: TASK 1.7 ::

# %%
def ransac(frames1,frames2,matches,N_iters=100,dist_thresh=15):
    # initialize
    max_inliers=0
    tnf=None
    # run random sampling
    for it in range(N_iters):
        # pick a random sample
        i = np.random.randint(0,frames1.shape[0])
        x_1,y_1,s_1,theta_1=frames1[i,:]
        j = matches[i,1]
        x_2,y_2,s_2,theta_2=frames2[j,:]

        # estimate transformation

        # COMPLETE BELOW #

        # theta = 
        # s = 
        # t_x =
        # t_y = 

        # evaluate estimated transformation
        X_1 = frames1[:,0]
        Y_1 = frames1[:,1]
        X_2 = frames2[matches[:,1],0]
        Y_2 = frames2[matches[:,1],1]

        X_1_prime = s*(X_1*np.cos(theta)-Y_1*np.sin(theta))+t_x
        Y_1_prime = s*(X_1*np.sin(theta)+Y_1*np.cos(theta))+t_y

        dist = np.sqrt((X_1_prime-X_2)**2+(Y_1_prime-Y_2)**2)

        inliers_indices = np.flatnonzero(dist<dist_thresh)
        num_of_inliers = len(inliers_indices)

        # keep if best
        if num_of_inliers>max_inliers:
            max_inliers=num_of_inliers
            best_inliers_indices = inliers_indices
            tnf = [t_x,t_y,s,theta]

    return (tnf,best_inliers_indices)

# %%
tnf,inliers_indices=ransac(frames1,frames2,matches)
filtered_matches = matches[inliers_indices,:]

# %%
# plot matches filtered with RANSAC
plt.figure()
plt.imshow(np.concatenate((im1,im2),axis=1))
for idx in range(filtered_matches.shape[0]):
    i=filtered_matches[idx,0]
    j=filtered_matches[idx,1]
    # plot dots at feature positions
    plt.gca().scatter([frames1[i,0],im1.shape[1]+frames2[j,0]], [frames1[i,1],frames2[j,1]], s=5, c='green')
    # plot lines
    plt.plot([frames1[i,0],im1.shape[1]+frames2[j,0]],[frames1[i,1],frames2[j,1]],linewidth=0.5)
plt.show()

# %% [markdown]
# # Part 2: Compact descriptors for image retrieval

# %% [markdown]
# In large scale retrieval the goal is to match a query image to a large database of images (for example the WWW or Wikipedia).
#
# The quality of an image match is measured as the number of geometrically verified feature correspondences between the query and a database image. While the techniques discussed in Part 1 are sufficient to do this, in practice they require too much memory to store the SIFT descriptors for all the detections in all the database images.
#
# In this part we will see how we can compute a *global* image descriptor from the set of SIFT descriptors using the bag-of-visual-words (BoVW) approach.
#
# Then, we will see how these global descriptors can be used to rapidly retrieve a shortlist of candidate database images given a query image. Finally, we will see how to re-rank the shortlist of candidates using a geometric verification technique that requires only the *detector frames* and their assigned visual word indices; remember the SIFT descriptors are only used to compute the compact BoVW descriptors and then discarded.

# %% [markdown]
# ## Download preprocessed dataset of paintings

# %%
print('downloading dictionary of SIFT features and precomputed BoVW descriptors for painting dataset...')
# !wget -c http://www.di.ens.fr/willow/teaching/recvis_orig/assignment1/paintings_imdb_SIFT_10k_preprocessed.mat
print('done!')

# %% [markdown]
# ## Load preprocessed dataset of paintings

# %% [markdown]
# We will now load the preprocessed dataset of paintings. The construction of this dataset has involved several steps.
#
#
# 1.   SIFT features were extracted from all painting in the dataset
# 2.   A global vocabulary of SIFT descriptors was computed using K-means clustering. These are the visual words of our dataset.
# 3.  The SIFT features for each painting were assigned to the nearest word, and a compact descriptor was generated for each painting. This compact descriptor consists in the normalized histogram of words. The histogram normalization itself involves 3 different steps:
#     - a) TF-IDF weighting: each word is re-weighted according to its TF-IDF value. This removes weights to words that are very common and therefore not too descriptive.
#     - b) Square-rooting: each element is square-rooted
#     - c) L2-normalization: The whole histogram is L2-normalized.

# %%
imdb=loadmat('paintings_imdb_SIFT_10k_preprocessed.mat')

feature_vocab=np.transpose(imdb['vocab'])
imdb_hists=imdb['index']
imdb_tfidf=imdb['idf']

imdb_url = lambda idx: imdb['images'][0][0][3][0][idx].item()

num_words = feature_vocab.shape[0]
num_paintings = imdb_hists.shape[1]

print('The vocabulary of SIFT features contains %s  visual words' % num_words)
print('The dictionary index contains %s histograms corresponding to each painting in the dataset' % num_paintings)
print('The tdf-idf vector has shape '+str(imdb_tfidf.shape))

# %%
painting = imread('data/queries/mistery-painting1.jpg')

[frames, descrs] = cyvlfeat.sift.sift(rgb2gray(painting), peak_thresh=0.01)

plt.figure()
plt.imshow(painting)
plotframes(frames,linewidth=1)

# %% [markdown]
# ### :: TASK 2.1 ::
#
# Construct a KDTree of the vocabulary for fast NN search. Then use the KDTree to find the closest word in the vocabulary to each descriptor of the query image.

# %%
from sklearn.neighbors import KDTree

##########################
#                        #
#  WRITE YOUR CODE HERE  #
#                        #
##########################

# %% [markdown]
# ### :: TASK 2.2 ::
# Compute the compact BoVW descriptor of the query image.

# %%
query_hist=np.zeros((num_words,1))

##########################
#                        #
#  WRITE YOUR CODE HERE  #
#                        #
##########################

# %%
# process histogram
query_hist = query_hist*imdb_tfidf
query_hist = np.sqrt(query_hist)
query_hist = query_hist/np.linalg.norm(query_hist)

# %% [markdown]
# ### :: TASK 2.3 ::
#
# Compute the matching score with each image from the database.

# %%
scores = np.zeros((1,num_paintings))

##########################
#                        #
#  WRITE YOUR CODE HERE  #
#                        #
##########################

# %%
# sort in descending order
scores_sorted_idx = np.argsort(-scores)
scores_sorted = scores.ravel()[scores_sorted_idx]

# %%
# plot top matches
N=10
top_N_idx = scores_sorted_idx.ravel()[:N]

plt.figure()
for i in range(N):
    # download images
    url = imdb_url(top_N_idx[i])      
    img = imread(url, pilmode='RGB')
    # choose subplot
    plt.subplot(int(np.ceil(N/5)),5,i+1)
    # plot
    plt.imshow(img)
    plt.axis('off')
    plt.title('score %1.2f' % scores_sorted.ravel()[i])

# %% [markdown]
# ## AUTHORSHIP STATEMENT
#
# I declare that the preceding work was the sole result of my own effort and that I have not used any code or results from third-parties.
#
# FILL IN YOUR NAME HERE
